# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.regressionplots import influence_plot

# %%
df=pd.read_csv("C:\\Users\\pradyumn\\Documents\\Assignment\\50_Startups.csv")

# %%
df.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.pairplot(df)

# %%
data=df.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
data.head(5)
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
data.corr()
# Out:
#              RDS      ADMS      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.pairplot(data)

# %%
model = smf.ols('Profit~RDS+ADMS+MKTS',data=data).fit()
#RDS	ADMS	MKTS	State	Profit

# %%
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MKTS             0.027228
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 15 Apr 2023   Prob (F-statistic):           4.53e-30
# Time:                        13:04:24   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
slradms = smf.ols('Profit~ADMS',data=data).fit()

# %%
slradms.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sat, 15 Apr 2023   Prob (F-statistic):              0.162
# Time:                        13:15:49   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %% [markdown]
# # After we build a simple linear regression model , we can see that administration has no signifcant p value

# %%
slrmar = smf.ols('Profit~MKTS',data=data).fit()
slrmar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Sat, 15 Apr 2023   Prob (F-statistic):           4.38e-10
# Time:                        13:33:50   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %% [markdown]
# ## SInce the p value is less than 0.05 we can say that it is a significant column

# %%
mlram = smf.ols('Profit~ADMS+MKTS',data=data).fit()
mlram.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Sat, 15 Apr 2023   Prob (F-statistic):           2.50e-10
# Time:                        13:38:00   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.022e+04   1.77e+04      1.143      0.259   -1.54e+04    5.58e+04
# ...

# %% [markdown]
# When we build the model together both of the columns have significant p value

# %% [markdown]
# # Model Validation Techniques
# # Two Techniques
# # 1) Collinearity Check - VIF
# # 2) Residual Analysis

# %%
rsqrds = smf.ols('RDS~ADMS+MKTS',data=data).fit().rsquared  
vifrds = 1/(1-rsqrds) 
vifrds
# Out:
# 2.4689030699947017

# %%
rsqadm = smf.ols('ADMS~RDS+MKTS',data=data).fit().rsquared  
vifadm = 1/(1-rsqadm) 
vifadm
# Out:
# 1.1750910070550458

# %%
rsqmks = smf.ols('MKTS~RDS+ADMS',data=data).fit().rsquared  
vifmks = 1/(1-rsqmks) 
vifmks
# Out:
# 2.3267732905308773

# %% [markdown]
# Since No value of VIF is greater than 5 , we can say that there is no collinearity problem. So we shall consider all columns for building the model

# %% [markdown]
# # Residual Analysis
# # Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm
sns.set_style(style='darkgrid')
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()  #User Defined Function Z = (x-mu)/sigma

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# Residual Vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RDS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "ADMS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "MKTS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics (checking Outliers or Influencers)
# # Two Techniques : 1. Cook's Distance & 2. Leverage value

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# There are no datapoints whose value is greater than 0.5

# %%
fig,ax=plt.subplots(figsize=(15,10))
fig=influence_plot(model,ax = ax)

# %%
k = data.shape[1]     # k = no.of features/columns & n = no. of datapoints
n = data.shape[0] 
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# # Improving the Model

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
data2=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
data2
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# # Model Deletion Diagnostics and Final Model

# %%
model2=smf.ols("Profit~RDS+ADMS+MKTS",data=data2).fit()

# %%
while model2.rsquared < 0.99:
    for c in [np.max(c)>1]:
        model2=smf.ols("Profit~RDS+ADMS+MKTS",data=data2).fit()
        (c,_)=model2.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        data2=data2.drop(data2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        data2
    else:
        final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=data2).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9626766170294073
# Thus model accuracy is improved to 0.9614129113440602
# Thus model accuracy is improved to 0.962593650298269
# Thus model accuracy is improved to 0.9638487279209415
# Thus model accuracy is improved to 0.9663901957918793
# Thus model accuracy is improved to 0.9706076169779905
# Thus model accuracy is improved to 0.9727840588916423
# Thus model accuracy is improved to 0.9734292907181952
# Thus model accuracy is improved to 0.9785801571833451
# Thus model accuracy is improved to 0.9777383743090916
# Thus model accuracy is improved to 0.9790510088977512
# Thus model accuracy is improved to 0.9790004461890552
# Thus model accuracy is improved to 0.9807878666153609
# Thus model accuracy is improved to 0.9838299343609735
# Thus model accuracy is improved to 0.9831149926392769
# Thus model accuracy is improved to 0.9833768520972176
# Thus model accuracy is improved to 0.9878892536376698
# ...

# %%
final_model.rsquared
# Out:
# 0.9882757054424702

# %%
data2
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   142107.34   91391.77  366168.42     Florida  166187.94
# 1   131876.90   99814.71  362861.36    New York  156991.12
# 2   130298.13  145530.06  323876.68     Florida  155752.60
# 3   120542.52  148718.95  311613.29    New York  152211.77
# 4   123334.88  108679.17  304981.62  California  149759.96
# 5    91992.39  135495.07  252664.93  California  134307.35
# 6    94657.16  145077.58  282574.31    New York  125370.37
# 7    91749.16  114175.79  294919.57     Florida  124266.90
# 8    76253.86  113867.30  298664.47  California  118474.03
# 9    67532.53  105751.03  304768.73     Florida  108733.99
# 10   77044.01   99281.34  140574.81    New York  108552.04
# 11   64664.71  139553.16  137962.62  California  107404.34
# 12   75328.87  144135.98  134050.07     Florida  105733.54
# 13   66051.52  182645.56  118148.20     Florida  103282.38
# 14   65605.48  153032.06  107138.38    New York  101004.64
# ...

# %% [markdown]
# # Model Predictions

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RDS':70000,"ADMS":90000,"MKTS":140000},index=[0])
new_data
# Out:
#      RDS   ADMS    MKTS
# 0  70000  90000  140000

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    104858.729408
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(data2)
pred_y
# Out:
# 0     165589.539700
# 1     158552.826483
# 2     156789.000710
# 3     149524.698853
# 4     150122.356712
# 5     126598.769555
# 6     130104.785747
# 7     127878.387928
# 8     117298.757074
# 9     111329.242429
# 10    110009.916133
# 11    102331.717613
# 12    109661.804131
# 13    103462.767086
# 14    101874.612012
# 15     97655.794577
# 16     97872.919535
# 17     96858.382686
# 18     98654.449007
# 19     93583.600868
# 20     91186.568204
# 21     88571.938968
# 22     84521.312916
# 23     78528.002935
# 24     76670.262623
# 25     73237.524757
# 26     68075.710756
# dtype: float64

# %% [markdown]
# # table containing R^2 value for each prepared model

# %%
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.988276
